# %%
import numpy as np
import random

# Define the new dimensionless lattice misfit strains
def define_dimensionless_strains(epsilon_a, gamma_0):
    # Dimensionless variables
    factor = epsilon_a / gamma_0
    
    epsilon_1 = np.array([
        [1 + factor, 0, 0],
        [0, factor, 0],
        [0, 0, factor],
    ])
    
    epsilon_2 = np.array([
        [factor, 0, 0],
        [0, 1 + factor, 0],
        [0, 0, factor],
    ])
    
    epsilon_3 = np.array([
        [factor, 0, 0],
        [0, factor, 0],
        [0, 0, 1 + factor],
    ])
    
    return epsilon_1, epsilon_2, epsilon_3

# Precompute stiffness tensor for cubic symmetry
def precompute_stiffness_tensor(anisoPar):
# Elastic constants
    C11 = 4/anisoPar
    C12 = C11/2
    C44 = 1
# compute elasticity tensor
    C = np.zeros((3, 3, 3, 3))
    for i in range(3):
        for j in range(3):
            for k in range(3):
                for l in range(3):
                    if i == j and k == l:
                        C[i, j, k, l] = C11 if i == k else C12
                    elif i == k and j == l:
                        C[i, j, k, l] = C44 if i != j else 0
    return C

# Precompute reciprocal space grid and kernel
def precompute_reciprocal_space_and_kernel(N, stiffness_tensor):
    q_range = np.fft.fftfreq(N, d=1 / (2 * np.pi))
    qx, qy, qz = np.meshgrid(q_range, q_range, q_range, indexing="ij")
    q_grid = np.stack((qx, qy, qz), axis=-1)

    B = np.zeros((N, N, N, 3, 3, 3, 3))
    for qx_idx in range(N):
        for qy_idx in range(N):
            for qz_idx in range(N):
                k = q_grid[qx_idx, qy_idx, qz_idx]
                if np.linalg.norm(k) == 0:
                    continue
                k_unit = k / np.linalg.norm(k)
                G_inv = np.einsum("ijmn,m,n->ij", stiffness_tensor, k_unit, k_unit)
                G = np.linalg.inv(G_inv) if np.linalg.det(G_inv) != 0 else np.zeros((3, 3))
                for i in range(3):
                    for j in range(3):
                        for k in range(3):
                            for l in range(3):
                                B[qx_idx, qy_idx, qz_idx, i, j, k, l] = (
                                    stiffness_tensor[i, j, k, l]
                                    - np.einsum(
                                        "mn,im,nj->",
                                        G,
                                        stiffness_tensor[:, :, i, j],
                                        stiffness_tensor[:, :, k, l],
                                    )
                                )
    return q_grid, B

# Compute strain field using dimensionless strain tensors
def compute_strain_field(lattice_spins, epsilon_1, epsilon_2, epsilon_3):
    N = lattice_spins.shape[0]
    strain_field = np.zeros((N, N, N, 3, 3))

    for x in range(N):
        for y in range(N):
            for z in range(N):
                spin = lattice_spins[x, y, z]
                if spin == 1:
                    strain_field[x, y, z] = epsilon_1
                elif spin == 2:
                    strain_field[x, y, z] = epsilon_2
                elif spin == 3:
                    strain_field[x, y, z] = epsilon_3

    return strain_field

# Compute elastic energy
def compute_elastic_energy(lattice_spins, q_grid, B, strain_ft):
    """
    Compute the total elastic energy using Fourier transforms and precomputed kernels.
    """
    N = lattice_spins.shape[0]
    elastic_energy = 0

    # Loop through all wavevectors in reciprocal space
    for qx_idx in range(N):
        for qy_idx in range(N):
            for qz_idx in range(N):
                # Exclude the k=0 point
                if np.allclose(q_grid[qx_idx, qy_idx, qz_idx], 0):
                    continue  # Skip the zero wavevector

                # Add contribution from this wavevector
                elastic_energy += np.real(
                    np.einsum(
                        "ij,ijkl,kl->", 
                        strain_ft[qx_idx, qy_idx, qz_idx],
                        B[qx_idx, qy_idx, qz_idx],
                        strain_ft[qx_idx, qy_idx, qz_idx].conj(),
                    )
                )

    # Normalize by the grid size (or volume factor)
    return elastic_energy

# Monte Carlo step with dimensionless strain
def monte_carlo_step(lattice_spins, temperature, q_grid, B, strain_ft, epsilon_1, epsilon_2, epsilon_3):
    N = lattice_spins.shape[0]
    x, y, z = np.random.randint(0, N, size=3)
    current_spin = lattice_spins[x, y, z]
    proposed_spin = random.choice([s for s in [1, 2, 3] if s != current_spin])
    
    # Compute new energy
    lattice_spins[x, y, z] = proposed_spin
    new_strain_field = compute_strain_field(lattice_spins, epsilon_1, epsilon_2, epsilon_3)
    strain_ft_new = np.fft.fftn(new_strain_field, axes=(0, 1, 2))
    E_new = compute_elastic_energy(lattice_spins, q_grid, B, strain_ft_new)

    # Revert to original state
    lattice_spins[x, y, z] = current_spin
    original_strain_field = compute_strain_field(lattice_spins, epsilon_1, epsilon_2, epsilon_3)
    strain_ft_original = np.fft.fftn(original_strain_field, axes=(0, 1, 2))
    E_old = compute_elastic_energy(lattice_spins, q_grid, B, strain_ft_original)

    # Calculate energy difference
    delta_E = E_new - E_old

    # Metropolis acceptance criterion
    prob = np.exp(-delta_E / temperature)
#    print(f"New E: {E_new}; Delta E: {delta_E}, Probability: {prob}")
    if delta_E <= 0 or random.random() < prob:
        lattice_spins[x, y, z] = proposed_spin
        strain_ft[:] = strain_ft_new
        return True
    return False

# Main simulation
def main():
    # Define lattice information
    lattice_size = 10
    lattice_spins = np.random.choice([1, 2, 3], size=(lattice_size, lattice_size, lattice_size))
#    lattice_spins = np.random.choice([1, 1, 1], size=(lattice_size, lattice_size, lattice_size))
    # Define the lattice misfit strain
    epsilon_a = 0.1
    gamma_0 = 0.4
    # Define the anisotropy parameter A=C44/Cp for the elasticity tensor
    anisoPar = 1
    # Define dimensionless temperature
    temperature = 0.20
    # Define time steps
    num_steps = 100

    # Compute dimensionless strain tensors
    epsilon_1, epsilon_2, epsilon_3 = define_dimensionless_strains(epsilon_a, gamma_0)
    # Compute dimensionless elasticity tensor
    stiffness_tensor = precompute_stiffness_tensor(anisoPar)
    q_grid, B = precompute_reciprocal_space_and_kernel(lattice_size, stiffness_tensor)
    strain_field = compute_strain_field(lattice_spins, epsilon_1, epsilon_2, epsilon_3)
    strain_ft = np.fft.fftn(strain_field, axes=(0, 1, 2))

    for step in range(1, num_steps + 1):
        accepted_moves = 0
        for _ in range(lattice_spins.size):
            if monte_carlo_step(lattice_spins, temperature, q_grid, B, strain_ft, epsilon_1, epsilon_2, epsilon_3):
                accepted_moves += 1
#        if step % 10 == 0:
        print(f"Timestep {step}: Accepted moves = {accepted_moves}")
        
    # Save final lattice configuration
    np.savetxt("final_spins.txt", lattice_spins.reshape(-1), fmt='%d')
    print("Simulation complete. Final spins saved to 'final_spins.txt'.")
    
if __name__ == "__main__":
    main()
# Out:
# /var/folders/gd/2993nnd54636wcntdzxdh3pw0000gn/T/ipykernel_73221/3344391324.py:150: RuntimeWarning: overflow encountered in exp
#   prob = np.exp(-delta_E / temperature)
# Timestep 1: Accepted moves = 340
# Timestep 2: Accepted moves = 151
# Timestep 3: Accepted moves = 114
# Timestep 4: Accepted moves = 71
# Timestep 5: Accepted moves = 39
# Timestep 6: Accepted moves = 36
# Timestep 7: Accepted moves = 32
# Timestep 8: Accepted moves = 39
# Timestep 9: Accepted moves = 21
# Timestep 10: Accepted moves = 31
# Timestep 11: Accepted moves = 18
# Timestep 12: Accepted moves = 17
# Timestep 13: Accepted moves = 19
# Timestep 14: Accepted moves = 18
# Timestep 15: Accepted moves = 15
# Timestep 16: Accepted moves = 14
# Timestep 17: Accepted moves = 14
# Timestep 18: Accepted moves = 8
# Timestep 19: Accepted moves = 11
# Timestep 20: Accepted moves = 2
# Timestep 21: Accepted moves = 8
# Timestep 22: Accepted moves = 8
# Timestep 23: Accepted moves = 2
# Timestep 24: Accepted moves = 1
# Timestep 25: Accepted moves = 4
# Timestep 26: Accepted moves = 3
# Timestep 27: Accepted moves = 4
# Timestep 28: Accepted moves = 5
# Timestep 29: Accepted moves = 3
# Timestep 30: Accepted moves = 0
# Timestep 31: Accepted moves = 1
# Timestep 32: Accepted moves = 2
# Timestep 33: Accepted moves = 2
# Timestep 34: Accepted moves = 0
# Timestep 35: Accepted moves = 2
# Timestep 36: Accepted moves = 2
# Timestep 37: Accepted moves = 0
# Timestep 38: Accepted moves = 1
# Timestep 39: Accepted moves = 0
# Timestep 40: Accepted moves = 3
# Timestep 41: Accepted moves = 5
# Timestep 42: Accepted moves = 2
# Timestep 43: Accepted moves = 6
# Timestep 44: Accepted moves = 8
# Timestep 45: Accepted moves = 4
# Timestep 46: Accepted moves = 5
# Timestep 47: Accepted moves = 9
# Timestep 48: Accepted moves = 1
# Timestep 49: Accepted moves = 1
# Timestep 50: Accepted moves = 3
# Timestep 51: Accepted moves = 1
# Timestep 52: Accepted moves = 0
# Timestep 53: Accepted moves = 4
# Timestep 54: Accepted moves = 0
# Timestep 55: Accepted moves = 1
# Timestep 56: Accepted moves = 0
# Timestep 57: Accepted moves = 1
# Timestep 58: Accepted moves = 0
# Timestep 59: Accepted moves = 0
# Timestep 60: Accepted moves = 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 191
#     188         print(f"Timestep {step}: Accepted moves = {accepted_moves}")
#     190 if __name__ == "__main__":
# --> 191     main()
#
# Cell In[32], line 185, in main()
#     183         accepted_moves = 0
#     184         for _ in range(lattice_spins.size):
# --> 185             if monte_carlo_step(lattice_spins, temperature, q_grid, B, strain_ft, epsilon_1, epsilon_2, epsilon_3):
#     186                 accepted_moves += 1
#     187 #        if step % 10 == 0:
#
# Cell In[32], line 138, in monte_carlo_step(lattice_spins, temperature, q_grid, B, strain_ft, epsilon_1, epsilon_2, epsilon_3)
#     136 new_strain_field = compute_strain_field(lattice_spins, epsilon_1, epsilon_2, epsilon_3)
#     137 strain_ft_new = np.fft.fftn(new_strain_field, axes=(0, 1, 2))
# --> 138 E_new = compute_elastic_energy(lattice_spins, q_grid, B, strain_ft_new)
#     140 # Revert to original state
#     141 lattice_spins[x, y, z] = current_spin
#
# Cell In[32], line 116, in compute_elastic_energy(lattice_spins, q_grid, B, strain_ft)
#     112                 continue  # Skip the zero wavevector
#     114             # Add contribution from this wavevector
#     115             elastic_energy += np.real(
# --> 116                 np.einsum(
#     117                     "ij,ijkl,kl->",
#     118                     strain_ft[qx_idx, qy_idx, qz_idx],
#     119                     B[qx_idx, qy_idx, qz_idx],
#     120                     strain_ft[qx_idx, qy_idx, qz_idx].conj(),
#     121                 )
#     122             )
#     124 # Normalize by the grid size (or volume factor)
#     125 return elastic_energy
#
# File ~/miniforge/lib/python3.12/site-packages/numpy/core/einsumfunc.py:1371, in einsum(out, optimize, *operands, **kwargs)
#    1369     if specified_out:
#    1370         kwargs['out'] = out
# -> 1371     return c_einsum(*operands, **kwargs)
#    1373 # Check the kwargs to avoid a more cryptic error later, without having to
#    1374 # repeat default values here
#    1375 valid_einsum_kwargs = ['dtype', 'order', 'casting']
#
# KeyboardInterrupt:

# %%
 np.savetxt("final_spins.txt", lattice_spins.reshape(-1), fmt='%d')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 np.savetxt("final_spins.txt", lattice_spins.reshape(-1), fmt='%d')
#
# NameError: name 'lattice_spins' is not defined
